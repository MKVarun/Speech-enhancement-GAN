# %% [markdown]
# ## **Import required libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import os
import time

# %% [markdown]
# ## **Load Data**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True, timeout_ms=120000*5)
# Out:
# Mounted at /content/drive

# %%
# !unzip -q '/content/drive/MyDrive/Speech_Project/train_16k_standardisation_zeroPadded.zip' -d '/content/Train'

# %%
# !unzip -q '/content/drive/MyDrive/Speech_Project/test_16k_standardisation_zeroPadded.zip' -d '/content/Test'

# %%
class my_Dataset(Dataset):
    # Characterizes a dataset for PyTorch
    def __init__(self, data_paths, target_paths, transform=None):
        self.data_paths = data_paths
        self.target_paths = target_paths
        self.transform = transform

    def __len__(self):
        return len(self.data_paths)

    def __getitem__(self, index):
        x = torch.from_numpy(np.expand_dims(np.load(self.data_paths[index]),axis = 0))
        y = torch.from_numpy(np.expand_dims(np.load(self.target_paths[index]),axis = 0))
        if self.transform:
            x = self.transform(x)

        return x, y


root_train_input = '/content/Train/train_16k_standardisation_zeroPadded/train_input/'
root_train_output = '/content/Train/train_16k_standardisation_zeroPadded/train_output/' 
root_test_input = '/content/Test/test_16k_standardisation_zeroPadded/test_input/'
root_test_output = '/content/Test/test_16k_standardisation_zeroPadded/test_output/' 

train_input = sorted(os.listdir('/content/Train/train_16k_standardisation_zeroPadded/train_input/'))
train_output = sorted(os.listdir('/content/Train/train_16k_standardisation_zeroPadded/train_output/'))
test_input = sorted(os.listdir('/content/Test/test_16k_standardisation_zeroPadded/test_input/'))
test_output = sorted(os.listdir('/content/Test/test_16k_standardisation_zeroPadded/test_output/'))

train_input = list(map(root_train_input.__add__,train_input))
train_output = list(map(root_train_output.__add__,train_output))
test_input = list(map(root_test_input.__add__,test_input))
test_output = list(map(root_test_output.__add__,test_output))
print(len(train_output), len(train_input), len(test_output), len(test_input))

train_set = my_Dataset(train_input,train_output) 
test_dataset = my_Dataset(test_input,test_output)
# Out:
# 40332 40332 3635 3635

# %%
round(train_set.__len__()*0.8) + round(train_set.__len__()*0.2)
# Out:
# 40332

# %%
generator=torch.Generator().manual_seed(123)
train_dataset, val_dataset = torch.utils.data.random_split(train_set, [round(train_set.__len__()*0.95),round(train_set.__len__()*0.05)],generator=generator)

# %%
train_loader = DataLoader(train_dataset,batch_size=200)
val_loader = DataLoader(val_dataset,batch_size=200)
test_loader = DataLoader(test_dataset,batch_size=200)

# %%
a,b = next(iter(train_loader))

# %%
a.shape, b.shape
# Out:
# (torch.Size([200, 1, 64, 64]), torch.Size([200, 1, 64, 64]))

# %% [markdown]
# ## **Data visualisation**

# %%
fig, axs = plt.subplots(1,2)
axs[0].imshow(a[9][0], cmap='jet')
axs[0].set_title('Noisy')
axs[1].imshow(b[9][0], cmap='jet')
axs[1].set_title('Clean')
plt.show()

# %%
a,b = next(iter(val_loader))
fig, axs = plt.subplots(1,2)
axs[0].imshow(a[1][0], cmap='jet')
axs[0].set_title('Noisy')
axs[1].imshow(b[1][0], cmap='jet')
axs[1].set_title('Clean')
plt.show()

# %%
a,b = next(iter(test_loader))
fig, axs = plt.subplots(1,2)
axs[0].imshow(a[10][0], cmap='jet')
axs[0].set_title('Noisy')
axs[1].imshow(b[10][0], cmap='jet')
axs[1].set_title('Clean')
plt.show()

# %% [markdown]
# ### **Exploration of mask values**

# %%
i = 9
plt.hist(a[i][0].ravel(),bins = 100)
plt.show()

plt.hist(b[i][0].ravel(),bins = 100)
plt.show()

# %% [markdown]
# ## **Architecture: CNN Model**

# %%
class CNN_TF(nn.Module):

    def __init__(self, kernel_size=4, stride=2, filter_size_1=64, filter_size_2=128, filter_size_3=256, filter_size_4=512, bottle_neck_size=100):
        super(CNN_TF, self).__init__()

        self.kernel_size = kernel_size
        self.stride = stride
        self.filter_size_1 = filter_size_1
        self.filter_size_2 = filter_size_2
        self.filter_size_3 = filter_size_3
        self.filter_size_4 = filter_size_4
        self.bottle_neck_size = bottle_neck_size

        self.conv2d_1 = nn.Conv2d(1, filter_size_1, kernel_size, stride)
        self.conv2d_2 = nn.Conv2d(filter_size_1, filter_size_2, kernel_size, stride)
        self.conv2d_3 = nn.Conv2d(filter_size_2, filter_size_3, kernel_size, stride)
        self.conv2d_4 = nn.Conv2d(filter_size_3, filter_size_4, kernel_size, stride)

        self.flatten = nn.Flatten()
        self.bottle_neck = nn.Linear(filter_size_4*2*2, bottle_neck_size)
        self.bn_to_deconv = nn.Linear(bottle_neck_size, filter_size_4*2*2)
        self.relu = nn.LeakyReLU()
        # self.sigmoid = nn.Sigmoid()
        self.sigmoid = nn.Tanh()

        self.batchnorm_encoder1 = nn.BatchNorm2d(filter_size_1)
        self.batchnorm_encoder2 = nn.BatchNorm2d(filter_size_2)
        self.batchnorm_encoder3 = nn.BatchNorm2d(filter_size_3)
        self.batchnorm_encoder4 = nn.BatchNorm2d(filter_size_4)

        self.batchnorm_decoder4 = nn.BatchNorm2d(filter_size_3)
        self.batchnorm_decoder3 = nn.BatchNorm2d(filter_size_2)
        self.batchnorm_decoder2 = nn.BatchNorm2d(filter_size_1)
        self.batchnorm_decoder1 = nn.BatchNorm2d(1)

        self.deconv2d_4 = nn.ConvTranspose2d(filter_size_4, filter_size_3, kernel_size, stride)
        self.deconv2d_3 = nn.ConvTranspose2d(filter_size_3, filter_size_2, kernel_size, stride)
        self.deconv2d_2 = nn.ConvTranspose2d(filter_size_2, filter_size_1, kernel_size, stride, output_padding=1)
        self.deconv2d_1 = nn.ConvTranspose2d(filter_size_1, 1, kernel_size, stride)


    def forward(self, spectrogram):

        x = self.conv2d_1(spectrogram)
        x = self.batchnorm_encoder1(x)
        x = self.relu(x)

        x = self.conv2d_2(x)
        x = self.batchnorm_encoder2(x)
        x = self.relu(x)

        x = self.conv2d_3(x)
        x = self.batchnorm_encoder3(x)
        x = self.relu(x)

        x = self.conv2d_4(x)
        x = self.batchnorm_encoder4(x)
        x = self.relu(x)

        x = self.flatten(x)
        x = self.bottle_neck(x)
        x = self.bn_to_deconv(x)
        x = torch.reshape(x, (-1,512,2,2))

        x = self.deconv2d_4(x)
        x = self.batchnorm_decoder4(x)
        x = self.relu(x)

        x = self.deconv2d_3(x)
        x = self.batchnorm_decoder3(x)
        x = self.relu(x)

        x = self.deconv2d_2(x)
        x = self.batchnorm_decoder2(x)
        x = self.relu(x)

        x = self.deconv2d_1(x)

        x = self.batchnorm_decoder1(x)
        # x = self.relu(x)

        x = self.sigmoid(x)
        
        # print(len(np.where(x.detach().cpu().numpy() < 0.9)))

        return x

# %%
model = CNN_TF()
yhat = model(torch.zeros(1,1,64,64))

# %%
from torchsummary import summary
summary(CNN_TF().cuda(),(1,64,64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 31, 31]           1,088
#        BatchNorm2d-2           [-1, 64, 31, 31]             128
#          LeakyReLU-3           [-1, 64, 31, 31]               0
#             Conv2d-4          [-1, 128, 14, 14]         131,200
#        BatchNorm2d-5          [-1, 128, 14, 14]             256
#          LeakyReLU-6          [-1, 128, 14, 14]               0
#             Conv2d-7            [-1, 256, 6, 6]         524,544
#        BatchNorm2d-8            [-1, 256, 6, 6]             512
#          LeakyReLU-9            [-1, 256, 6, 6]               0
#            Conv2d-10            [-1, 512, 2, 2]       2,097,664
#       BatchNorm2d-11            [-1, 512, 2, 2]           1,024
#         LeakyReLU-12            [-1, 512, 2, 2]               0
#           Flatten-13                 [-1, 2048]               0
#            Linear-14                  [-1, 100]         204,900
#            Linear-15                 [-1, 2048]         206,848
#   ConvTranspose2d-16            [-1, 256, 6, 6]       2,097,408
#       BatchNorm2d-17            [-1, 256, 6, 6]             512
#         LeakyReLU-18            [-1, 256, 6, 6]               0
#   ConvTranspose2d-19          [-1, 128, 14, 14]         524,416
#       BatchNorm2d-20          [-1, 128, 14, 14]             256
#         LeakyReLU-21          [-1, 128, 14, 14]               0
#   ConvTranspose2d-22           [-1, 64, 31, 31]         131,136
#       BatchNorm2d-23           [-1, 64, 31, 31]             128
#         LeakyReLU-24           [-1, 64, 31, 31]               0
#   ConvTranspose2d-25            [-1, 1, 64, 64]           1,025
#       BatchNorm2d-26            [-1, 1, 64, 64]               2
#              Tanh-27            [-1, 1, 64, 64]               0
# ================================================================
# Total params: 5,923,047
# Trainable params: 5,923,047
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 4.56
# Params size (MB): 22.59
# Estimated Total Size (MB): 27.17
# ----------------------------------------------------------------

# %% [markdown]
# ## **Training loop**

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
# shape = (n, 1, 64, 64)
def train_cnn(train_loader,val_loader, n_epochs=20, batch_size=200, lr=0.0002):
    cnn_tf = CNN_TF().cuda()
    cnn_tf.double()
    start_epoch = 0
    running_loss = {'train': [], 'val': []}

    params = cnn_tf.parameters()
    print('params calculated')

    opt = optim.Adam(params, lr=lr)

    ### Only keep uncommnted when trying to load from before
    path = "/content/drive/MyDrive/Speech_Project/implicit_CNN/checkpoint_cnntf_implicit_mask_tanh_epoch_20.pth.tar"
    ckpt = torch.load(path)
    cnn_tf = ckpt['model']
    opt = ckpt['optimizer']
    start_epoch = ckpt['epoch']
    running_loss = ckpt['loss']
    print("\nRestored From Previous state...\n")

    criterion = nn.MSELoss()  
    total_loss = 0
    val_loss = 0
    print('loaded loss and opt')

    for i in range(start_epoch, n_epochs):

        opt.zero_grad()
        epoch_loss = 0
        val_loss = 0
        start = time.time()
        for j, (batch_input,batch_output) in enumerate(train_loader):
            # print(batch_input.shape, batch_output.shape)
            model_output = cnn_tf(batch_input.cuda())
  
            # print(model_output.shape)
            loss = criterion(model_output, batch_output.cuda())

            loss.backward()
            opt.step()

            epoch_loss+=loss.item()
            del batch_input, batch_output

        print('\n\n Epoch ',i+1 ,' : Train Loss = ', epoch_loss/len(train_loader), '  time taken = ', time.time()-start,'s')
        running_loss['train'].append(epoch_loss/len(train_loader))

        for val_input, val_output in val_loader:
          model_output = cnn_tf(val_input.cuda())
          valloss = criterion(model_output, val_output.cuda())
          val_loss += valloss.item()
          del valloss, model_output

        print('             Val Loss = ', val_loss/len(val_loader)) 
        running_loss['val'].append(val_loss/len(val_loader))
        
        # Save model state after each epoch
        state = {'model': cnn_tf,
                'optimizer': opt,
                 'epoch':int(i+1),
                 'loss':running_loss}

        filename = '/content/drive/My Drive/Speech_Project/implicit_CNN/checkpoint_cnntf_implicit_mask_tanh_epoch_'+str(i+1)+'.pth.tar'
        torch.save(state, filename)
        torch.cuda.empty_cache()
        
        print('             Checkpointed model state')
    return running_loss

# %%
running_loss = train_cnn(train_loader,val_loader,n_epochs=50, lr = 0.002)
# Out:
# params calculated
#
# Restored From Previous state...
#
# loaded loss and opt
#
#
#  Epoch  21  : Train Loss =  0.347867169819074   time taken =  290.42684531211853 s
#              Val Loss =  0.34427997337512234
#              Checkpointed model state
#
#
#  Epoch  22  : Train Loss =  0.3399977636750528   time taken =  275.5699052810669 s
#              Val Loss =  0.3488039225476282
#              Checkpointed model state
#
#
#  Epoch  23  : Train Loss =  0.34010822332414664   time taken =  263.42097568511963 s
#              Val Loss =  0.3440326064980748
#              Checkpointed model state
#
#
#  Epoch  24  : Train Loss =  0.3402743808128907   time taken =  263.4873433113098 s
#              Val Loss =  0.35023630647803944
#              Checkpointed model state
#
#
#  Epoch  25  : Train Loss =  0.3453184001758869   time taken =  264.2814838886261 s
#              Val Loss =  0.3541164126129894
#              Checkpointed model state
#
#
#  Epoch  26  : Train Loss =  0.34928293979598446   time taken =  264.16610527038574 s
#              Val Loss =  0.3688377644645492
#              Checkpointed model state
#
#
#  Epoch  27  : Train Loss =  0.3569031676995369   time taken =  264.0406000614166 s
#              Val Loss =  0.3673539463144069
#              Checkpointed model state
#
#
#  Epoch  28  : Train Loss =  0.3570886638408269   time taken =  264.0972993373871 s
#              Val Loss =  0.34051101115135435
#              Checkpointed model state
#
#
#  Epoch  29  : Train Loss =  0.3302917375822882   time taken =  263.2417371273041 s
#              Val Loss =  0.32962622898665356
#              Checkpointed model state
#
#
#  Epoch  30  : Train Loss =  0.3273483961349642   time taken =  263.30201745033264 s
#              Val Loss =  0.3278731485072706
#              Checkpointed model state
#
#
#  Epoch  31  : Train Loss =  0.31692409303377117   time taken =  263.23699259757996 s
#              Val Loss =  0.3252051257416525
#              Checkpointed model state
#
#
#  Epoch  32  : Train Loss =  0.3194774782049368   time taken =  263.23573422431946 s
#              Val Loss =  0.3329063698920733
#              Checkpointed model state
#
#
#  Epoch  33  : Train Loss =  0.32589157872135166   time taken =  263.102135181427 s
#              Val Loss =  0.33029026871792433
#              Checkpointed model state
#
#
#  Epoch  34  : Train Loss =  0.32425528040609164   time taken =  263.0320653915405 s
#              Val Loss =  0.33129290204662387
#              Checkpointed model state
#
#
#  Epoch  35  : Train Loss =  0.31960770122320703   time taken =  262.8020715713501 s
#              Val Loss =  0.32920295566707386
#              Checkpointed model state
#
#
#  Epoch  36  : Train Loss =  0.32664537977815444   time taken =  262.9578540325165 s
#              Val Loss =  0.33729887156805943
#              Checkpointed model state
#
#
#  Epoch  37  : Train Loss =  0.32337496660059567   time taken =  263.0250709056854 s
#              Val Loss =  0.3581497027386437
#              Checkpointed model state
#
#
#  Epoch  38  : Train Loss =  0.3418703897829938   time taken =  263.112909078598 s
#              Val Loss =  0.3523856019325715
#              Checkpointed model state
#
#
#  Epoch  39  : Train Loss =  0.34092319057816795   time taken =  263.13775753974915 s
#              Val Loss =  0.32733012207356044
#              Checkpointed model state
#
#
#  Epoch  40  : Train Loss =  0.3178971462848372   time taken =  263.0894629955292 s
#              Val Loss =  0.31570478421209053
#              Checkpointed model state
#
#
#  Epoch  41  : Train Loss =  0.30688511757182185   time taken =  263.0695626735687 s
#              Val Loss =  0.3091699406603231
#              Checkpointed model state
#
#
#  Epoch  42  : Train Loss =  0.3020552589212439   time taken =  263.28709745407104 s
#              Val Loss =  0.3102441443607428
#              Checkpointed model state
#
#
#  Epoch  43  : Train Loss =  0.30401161286144435   time taken =  263.12933468818665 s
#              Val Loss =  0.31432999599176975
#              Checkpointed model state
#
#
#  Epoch  44  : Train Loss =  0.3071200604107926   time taken =  263.0407929420471 s
#              Val Loss =  0.3124671137317759
#              Checkpointed model state
#
#
#  Epoch  45  : Train Loss =  0.3083081987348039   time taken =  263.0392949581146 s
#              Val Loss =  0.3215516967726953
#              Checkpointed model state
#
#
#  Epoch  46  : Train Loss =  0.3147007098992917   time taken =  263.0870976448059 s
#              Val Loss =  0.31332118030040684
#              Checkpointed model state
#
#
#  Epoch  47  : Train Loss =  0.3113727772509873   time taken =  262.94164991378784 s
#              Val Loss =  0.3211442099855215
#              Checkpointed model state
#
#
#  Epoch  48  : Train Loss =  0.31154932604071944   time taken =  263.1680223941803 s
#              Val Loss =  0.31642016532626116
#              Checkpointed model state
#
#
#  Epoch  49  : Train Loss =  0.3085592846252526   time taken =  263.00386214256287 s
#              Val Loss =  0.309945705401197
#              Checkpointed model state
#
#
#  Epoch  50  : Train Loss =  0.2984589443238145   time taken =  262.99942684173584 s
#              Val Loss =  0.30434971513560966
#              Checkpointed model state

# %% [markdown]
# ### **Loss curves**

# %%
num_epochs = range(0,len(running_loss['train']))

plt.figure(figsize = (8,6))
plt.plot(num_epochs, running_loss['train'],'b')
plt.plot(num_epochs, running_loss['val'],'r')
plt.legend(['train','val'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# Deaddduu

# %% [markdown]
# ## **Evaluation on test data**

# %%
test_loader = DataLoader(test_dataset,batch_size=200)

# %%
criterion  = nn.MSELoss()
loss = 0
for batch_input, batch_output in test_loader:
    loss += criterion(batch_input,batch_output).item()

# %%
print('Testset loss = ', loss/len(test_loader))
# Out:
# Testset loss =  0.008428970991176206

# %%
model = CNN_TF().cuda()
model = model.double()
load_path = '/content/drive/MyDrive/Speech_Project/implicit_CNN/checkpoint_cnntf_implicit_mask_epoch_50.pth.tar'
state_dict = torch.load(load_path)
model.load_state_dict(state_dict['model'].state_dict())

loss = 0
predicted = []
for j, (batch_input,batch_output) in enumerate(test_loader):
    model_output = model(batch_input.cuda())
    loss += criterion(model_output,batch_output.cuda()).item()
    predicted.append(model_output.detach().cpu().numpy())
print('Model output testset loss = ', loss/len(test_loader))
# Out:
# Model output testset loss =  0.5686010083514865

# %%
a,b = next(iter(test_loader))
c = model(a.cuda()).detach().cpu()
fig, axs = plt.subplots(1,3)
axs[0].imshow(a[8][0], cmap='jet')
axs[0].set_title('Noisy')
axs[1].imshow(b[8][0], cmap='jet')
axs[1].set_title('Clean')
axs[2].imshow(c[8][0], cmap='jet')
axs[2].set_title('Predicted')
plt.show()

# %% [markdown]
# ## **Save predicted GTgrams**

# %%
from scipy.io import savemat, loadmat

# %%
root = '/content/Test/test_16k_standardisation_zeroPadded/test_input/'
os.mkdir('/content/predicted/')
save_root = '/content/predicted/'
test_files = os.listdir(root)
audios = []
for name in test_files:
    audio = '_'.join(name.split('_')[:3])
    if audio not in audios:
      audios.append(audio)

# %%
for i,name in enumerate(audios):
  input_files = sorted(list(filter(lambda x: x.startswith(name + "_") , test_files)))
  positions = np.argsort([int(x.split('.')[0].split('_')[-1])-1 for x in input_files])
  #ordered_files = input_files[positions]
  
  input_arr = []
  for filename in input_files:
    x = np.expand_dims(np.load(root+filename),axis = 0)
    input_arr.append(x)
  model_input = torch.from_numpy(np.array(input_arr))
  # model_output = model(model_input.cuda()).detach().cpu().numpy()
  model_output = torch.div(model(model_input.cuda()).detach().cpu(), model_input).numpy()

  arranged_out = model_output[positions]
  concat_out = np.concatenate((arranged_out), axis = 2)

  savemat( save_root+name+'.mat', mdict = {'PRED_SPEC': concat_out[0]})

# %%
# !zip -q -r CNN_implicit_standardised_with_division 'predicted'

# %%
# !cp '/content/CNN_implicit_standardised_with_division.zip' '/content/drive/My Drive/Speech_Project/Latest_Results/'
